# %% [markdown]
# - 머신러닝 : 정형 데이터를 다룰 때 유리 (표의 형태)
# - 딥러닝 : 정형, 비정형, 준정형

# %%
from sklearn.datasets import load_iris

iris_data = load_iris()
type(iris_data)
# Out:
# sklearn.utils._bunch.Bunch

# %% [markdown]
# Bunch: 기본적으로 dict와 매우 비슷한 구조/ key를 통한 접근을 .을 통해 할 수 있음

# %%
iris_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris_data["data"].shape
# Out:
# (150, 4)

# %%
#target(label)
iris_data["target"][:3]
# Out:
# array([0, 0, 0])

# %%
iris_data["target_names"]
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import pandas as pd

iris_df = pd.DataFrame(data=iris_data["data"], columns = iris_data["feature_names"])
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df["target"] = iris_data["target"]
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
