# %%
## 함수 선언부

## 전역 변수부
katok = ['다현', '정연', '쯔위', '사나', '지효']

## 메인 코드부
print(katok)

## 데이터 추가 (모모가 카톡 1회)
# 1단계 : 빈칸 확보
katok.append(None)
katok[5]='모모'
print(katok)

## 데이터 삽입 (미나가 카톡 연속 40회)
# 1단계 : 빈칸 확보
katok.append(None)
# 2단계 : 한칸씩 뒤로 이동
katok[6] = katok[5]
katok[5] = None
katok[5] = katok[4]
katok[4] = None
katok[4] = katok[3]
katok[3] = None
# 3단계 : 미나를 빈 자리에 넣기
katok[3] = '미나'
print(katok)

## 데이터 삭제 (사나가 카톡 차단)
# 1단계 : 지우기
katok[4] = None
# 2단계 : 한칸씩 앞으로 이동(마지막 친구 까지)
katok[4] = katok[5]
katok[5] = None
katok[5] = katok[6]
katok[6] = None
# 3단계 : 빈칸 제거
del(katok[6])
print(katok)
# Out:
# ['다현', '정연', '쯔위', '사나', '지효']
# ['다현', '정연', '쯔위', '사나', '지효', '모모']
# ['다현', '정연', '쯔위', '미나', '사나', '지효', '모모']
# ['다현', '정연', '쯔위', '미나', '지효', '모모']

# %%
## 함수
def add_data(friend):
  katok.append(None) # 1단계 : 빈칸 추가
  kLen = len(katok) # 배열의 길이 파악
  katok[kLen-1] = friend

def insert_data(position, friend):
  katok.append(None)
  kLen = len(katok)
  # 2단계: 한칸씩 오른쪽으로
  for i in range(kLen-1, position, -1):
    katok[i] = katok[i-1]
    katok[i-1] = None
  # 3단계
  katok[position] = friend

def delete_data(position):
  katok[position] = None # 1단계: 빈칸 추가
  # 2단계 : 한칸씩 왼쪽으로
  kLen = len(katok)
  for i in range(position+1, kLen, 1):
    katok[i-1] = katok[i]
    katok[i] = None
  # 3단계 : 마지막 칸 삭제  
  del(katok[kLen-1])

## 변수
katok = []

## 메인
add_data('다현')
add_data('정연')
add_data('쯔위')
add_data('사나')
add_data('지효')
print(katok)
add_data('모모')
print(katok)

insert_data(3, '미나')
print(katok)

delete_data(4)
# Out:
# ['다현', '정연', '쯔위', '사나', '지효']
# ['다현', '정연', '쯔위', '사나', '지효', '모모']
# ['다현', '정연', '쯔위', '미나', '사나', '지효', '모모']
