# %% [markdown]
# # DAY2
# ## python

# %%
a=0
b=10
print(f"{'값이 위치할수있는 장소'}")
# Out:
# 값이 위치할수있는 장소

# %%
print("a\rb")
# Out:
# b

# %%
x=10
y='문자열'
print(f'숫자{x},문자{y}')
# Out:
# 숫자10,문자문자열

# %% [markdown]
# 채움 및 정렬

# %%
print(f'[{x:10}]')
print(f'[{11111111111:10}]')
print(f'[{x:<10}]')
print(f'[{x:^10}]')
print(f'[{x:>10}]')
# Out:
# [        10]
# [11111111111]
# [10        ]
# [    10    ]
# [        10]

# %%
x1=1.1
print(f'[{x:>5d}]')
print(f'[{x1:>5}]')
# Out:
# [   10]
# [  1.1]

# %%
print(f"[{1:5d}],[{-2:5d}],[{3:5d}]")
print(f"[{1:05}],[{-2:05}],[{3:05}]")
print(f"[{1:#<5d}],[{-2:#^5d}],[{3:#>5d}]")
print(f"[{1:=5d}],[{-2:=5d}],[{3:=5d}]")
print(f"[{1:#=5d}],[{-2:#=5d}],[{3:#=5d}]")
# Out:
# [    1],[   -2],[    3]
# [00001],[-0002],[00003]
# [1####],[#-2##],[####3]
# [    1],[-   2],[    3]
# [####1],[-###2],[####3]

# %%
print(f"[{-1000000000000:=5,}]")
print(f"[{-1000000000000:=5_}]")
print(f"[{-1000000000000:=5e}]")
# Out:
# [-1,000,000,000,000]
# [-1_000_000_000_000]
# [-1.000000e+12]

# %%
print(f"[{10:5b}],[{10:5o}],[{10:5x}],[{10:5X}]")
# Out:
# [ 1010],[   12],[    a],[    A]

# %%
a=10
print('{%s%%}'%(a))
print(f'{{{a}%}}')
# Out:
# {10%}
# {10%}

# %% [markdown]
# 입력

# %%
a=10
a=input(f'초기 a값={a} \n새로운 입력:')
input(f'a값={a} \n새로운 입력:')
# Out:
# 초기 a값=10
# 새로운 입력:4000
# a값=4000
# 새로운 입력:s
# 's'

# %%
a=int(input())
a+10
# Out:
# 10
# 20

# %%
a,b,c,d=input().split()

int(a)+int(b)
a+b
# Out:
# 1 2 3 4
# 3

# %%
'문자,문자,문자'.split(',')
# Out:
# ['문자', '문자', '문자']

# %% [markdown]
# 입력 형변환

# %%
#1
a=int(input())
b=int(input())
c=int(input())
d=int(input())
#2
a,b,c,d=input().split()
a=int(a)
b=int(b)
c=int(c)
d=int(d)
#3
a,b,c,d=map(int,input().split())
print(type(a))
print(type(b))
print(type(c))
print(type(d))

# %%
a,b,c,d=map(eval,input().split())#map객체는 1회성이다
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# a s d f
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-0cf2b3233bcc> in <module>
# ----> 1 a,b,c,d=map(eval,input().split())#map객체는 1회성이다
#       2 print(type(a))
#       3 print(type(b))
#       4 print(type(c))
#       5 print(type(d))
#
# <string> in <module>
#
# NameError: name 's' is not defined

# %% [markdown]
# Q

# %%
이름,나이=input("이름,나이를 입력하시오(구분자 ',')").split(',')
나이=int(나이)
print(f"{이름}님의 나이는 {나이}세 입니다.")
# Out:
# 이름,나이를 입력하시오(구분자 ',')홍길동,38
# 홍길동님의 나이는 38세 입니다.

# %% [markdown]
# 연산자

# %%
#산술 숫자->숫자
a=10**2#불변 ** 불변
print(a+1)
print(a-1)
print(a*1)
print(a/1)
print(a//1)
print(1.1/1)
print(1.1//1.0)
print(int(10.1%1))
# Out:
# 101
# 99
# 100
# 100.0
# 100
# 1.1
# 1.0
# 0

# %%
#비교 연산은 객체의 값을 비교한다
1==1
#2==1
1!=1
1>2
1<2
1>=2
1<=2
# Out:
# True

# %%
ord('s')
# Out:
# 115

# %%
type(chr(115))
# Out:
# str

# %%
'a'<'b'
# Out:
# True

# %%
224<=124
# Out:
# False

# %%
'caa'<='acb'
# Out:
# False

# %%
#논리 1<X<10==> 피연산 조건 피연산=>논리 논리연산자  피연산 조건 피연산=>논리 => 1<X and X<10 => 1<x<10
X=5
not(1<X and X<10)
1>X or X>10
# Out:
# False

# %% [markdown]
# 대입

# %%
a=10
b=20
a = b = 10
a + b + c

# %%
1산술 2대입 
c + b *= d

# %%
a=10
b=10
a==b
# Out:
# True

# %%
1 in {1,2,3}
3 in {1:2,2:4,3:2}
# Out:
# True

# %%
#원소값 in 차원구조
'b' not in 'data'
4 in [[1,2,3,4]]
# Out:
# False

# %%
'안하' in '안안녕하세요'
# Out:
# False

# %%
a=2
b=2
print(a==b,a is b)
# Out:
# True True

# %%
# is 가 참이라면 ==은 절대적으로 참이다
# == 이 참이면 is 는 거짓일 수 있다.

# %% [markdown]
# Q

# %%
a,b,c,d,e=map(int,input('정수 5개 입력(구분자" "):').split())
print(abs(a)+abs(b)+abs(c)+abs(d)+abs(e))
# Out:
# 정수 5개 입력(구분자" "):35 -20 10 0 55
# 120

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
a=100
b=200
print(f'{a}+{b}={a+b}')
# Out:
# 100+200=300

# %%
a,b=map(eval,input('두수입력(구분자" "):').split())
print(f'+={a+b}\n-={a-b}\n*={a*b}\n/={a//b}\n%={a%b}')
# Out:
# 두수입력(구분자" "):2 1
# +=3
# -=1
# *=2
# /=2
# %=0

# %%
연필수=534
print(f'학생당 연필:{연필수//30}\n남은 연필수:{연필수%30}')
# Out:
# 학생당 연필:17
# 남은 연필수:24

# %%
end=int(input("정수입력:"))
print(f'초기입력:{end}\n결과:{(end//100)*100}')
# Out:
# 정수입력:4512
# 초기입력:4512
# 결과:4500
