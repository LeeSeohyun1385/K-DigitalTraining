# %%
## 함수
def findMinIndex(ary):
  minIdx = 0
  for i in range(1, len(ary)):
    if (ary[minIdx] > ary[i]):
      minIdx = i
  return minIdx


## 전역
testAry = [55, 88, 33, 77]
## 메인
minPos = findMinIndex(testAry)
print('최솟값:', testAry[minPos])
# Out:
# 최솟값: 33

# %% [markdown]
# # 선택 정렬

# %%
import random
before = [random.randint(30,200) for _ in range(10)]
before
# Out:
# [104, 187, 137, 52, 179, 82, 170, 34, 67, 181]

# %%
## 함수
def findMinIndex(ary):
  minIdx = 0
  for i in range(1, len(ary)):
    if (ary[minIdx] > ary[i]):
      minIdx = i
  return minIdx

## 변수
before = [random.randint(30,200) for _ in range(10)]
after = []

## 메인
print('정렬전:',before)
for _ in range(len(before)):
  minPos = findMinIndex(before)
  after.append(before[minPos])
  del(before[minPos])
print('정렬후:', after)
# Out:
# 정렬전: [170, 137, 144, 60, 67, 178, 93, 97, 117, 49]
# 정렬후: [49, 60, 67, 93, 97, 117, 137, 144, 170, 178]

# %%
### 함수
import random
def  selectSort(ary) :
    n = len(ary)
    for i in range(0, n-1) : # 사이클 3번
        minIdx = i
        for k in range(i+1, n) :
            if (ary[minIdx] > ary[k]) :
                minIdx = k
        ary[i], ary[minIdx] = ary[minIdx], ary[i]

    return ary

## 변수
dataAry = [random.randint(30, 200) for _ in range(100)]

## 메인
print('정렬 전-->', dataAry)
dataAry = selectSort(dataAry)
print('정렬 후-->', dataAry)
# Out:
# 정렬 전--> [189, 129, 178, 114, 30, 109, 42, 139, 34, 152, 145, 147, 141, 59, 153, 194, 101, 68, 64, 163, 184, 172, 165, 99, 135, 93, 96, 155, 178, 180, 149, 77, 97, 65, 174, 97, 40, 140, 80, 33, 187, 44, 151, 97, 33, 143, 47, 136, 150, 156, 162, 110, 114, 81, 105, 145, 143, 134, 37, 195, 141, 113, 173, 198, 31, 120, 87, 77, 115, 64, 103, 131, 130, 89, 179, 186, 86, 180, 82, 52, 175, 87, 151, 165, 122, 48, 79, 126, 65, 125, 42, 71, 94, 200, 194, 138, 139, 165, 120, 102]
# 정렬 후--> [30, 31, 33, 33, 34, 37, 40, 42, 42, 44, 47, 48, 52, 59, 64, 64, 65, 65, 68, 71, 77, 77, 79, 80, 81, 82, 86, 87, 87, 89, 93, 94, 96, 97, 97, 97, 99, 101, 102, 103, 105, 109, 110, 113, 114, 114, 115, 120, 120, 122, 125, 126, 129, 130, 131, 134, 135, 136, 138, 139, 139, 140, 141, 141, 143, 143, 145, 145, 147, 149, 150, 151, 151, 152, 153, 155, 156, 162, 163, 165, 165, 165, 172, 173, 174, 175, 178, 178, 179, 180, 180, 184, 186, 187, 189, 194, 194, 195, 198, 200]
