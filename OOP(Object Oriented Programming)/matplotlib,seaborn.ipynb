# %% [markdown]
# # matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.array([0,2,4,6])#막대가 위치할 장소
y=[[5,8,4,3],[1,2,3,4],[5,7,9,2]]
plt.bar(x,y[0],color='r',width=0.5)
plt.bar(x+0.5,y[1],color='g',width=0.5)
plt.bar(x+1,y[2],color='b',width=0.5)
plt.xlabel('ck_d')
plt.xticks(x,('a','b','c','d'))
plt.ylabel('num_data')
plt.yticks([2,4,6,8,10])
plt.show()

# %%
data=np.array(y)
data
# Out:
# array([[5, 8, 4, 3],
#        [1, 2, 3, 4],
#        [5, 7, 9, 2]])

# %%
x=np.arange(data.shape[1])
x
# Out:
# array([0, 1, 2, 3])

# %%
color=['r','g','b']
name=['A','B','C']

# %%
for i in range(3):
  plt.bar(x,data[i],bottom=np.sum(data[:i],axis=0),color=color[i],label=name[i])
plt.xticks(x,('a','b','c','d'))
plt.legend()
plt.show()

# %%
x=np.random.normal(size=100000)
x.shape
plt.hist(x)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %%
data=np.random.randn(100,6)
data.shape
plt.boxplot(data)
plt.show()

# %%
data=sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
np.unique(data['species'])
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
x=data['sepal_length']

# %%
plt.plot(x)

# %%
plt.bar(np.arange(len(x)),x)
# Out:
# <BarContainer object of 150 artists>

# %%
plt.plot(x,'r--*')
plt.bar(np.arange(len(x)),x)
# Out:
# <BarContainer object of 150 artists>

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb84397cca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb8439aa280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb84397c9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb8439aa820>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb8439aaaf0>],
#  'means': []}

# %%
plt.hist(x)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # seaborn

# %%
sns.distplot(x,kde=True,rug=True)#kde완만,rug구성요소명확하게
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(data['sepal_width'],kde=True,rug=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %%
for i in data.columns:
  if i=='species':
    break
  sns.distplot(data[i],kde=True,rug=True)
  plt.show()#출력, 초기화
    #따로따로 그리기 위해
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue='species')#정답'species'에관해 데이터별로 따로 나눠서 보여줌 #hue 조건

# %%
data=[123,45,6,32,10]
data_l=['A','B','C','D','E']
plt.pie(data,labels=data_l,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb8426cbe50>,
# ...
#  [Text(-0.23808348595575934, 1.0739256276461393, 'A'),
#   Text(-0.5079236521888623, -0.9757118240275291, 'B'),
#   Text(0.2847007402899453, -1.0625184650058357, 'C'),
#   Text(0.8001108601254385, -0.7548659559877708, 'D'),
#   Text(1.0883857714804555, -0.1594252565903338, 'E')],
#  [Text(-0.12986371961223236, 0.5857776150797123, '56.94%'),
#   Text(-0.27704926483028847, -0.5322064494695613, '20.83%'),
#   Text(0.1552913128854247, -0.5795555263668194, '2.78%'),
#   Text(0.4364241055229664, -0.41174506690242046, '14.81%'),
#   Text(0.5936649662620666, -0.08695923086745479, '4.63%')])

# %%
data=sns.load_dataset('tips')

# %%
sns.pairplot(data)

# %% [markdown]
# 1. 데이터 수집

# %% [markdown]
# 2. 데이터 분석 EDA(탐색적 데이터 분석)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
plt.scatter(data['total_bill'],data['tip'])
plt.plot([data['total_bill'].max(),data['total_bill'].min()],[data['tip'].max(),data['tip'].min()])

# %%
sns.regplot(x='total_bill',y='tip',data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='time',data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='day',data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',data=data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.countplot(x='time',hue='sex',data=data)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.barplot(x='time',y='tip',data=data)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.barplot(x='sex',y='tip',data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x='smoker',y='tip',data=data)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(x='day',y='tip',data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='size',y='tip',data=data)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.violinplot(x='day',y='tip',hue='smoker',data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x='day',y='tip',hue='smoker',data=data)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day',y='tip',data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# 가설을 검증

# %%
data['sex']= np.where(data['sex']=='Female',0,1)

# %%
data['smoker']= np.where(data['smoker']=='No',0,1)
data['time']= np.where(data['time']=='Dinner',0,1)
data

# %%
np.unique()

# %%
sns.pairplot(data)

# %%
for i in data.columns:
  if i in['tip','day']:
    continue
  sns.regplot(x=i,y='tip',data=data)
  plt.show()
